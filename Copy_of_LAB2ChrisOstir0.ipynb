# %% [markdown]
# <a href="https://colab.research.google.com/github/cmostir/Lab--/blob/main/Copy_of_LAB2ChrisOstir0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In my ER diagram I had 6 entities. Customer, Animal, Food, Pet Store, Transactions for a pet and transactions for pet food. I connected all of these entities by looking at what they have in common and tried to think how a pet shop is run. I designed the ER diagram this way because I felt the entities I chose were most logical. I connected things like animals being fed food and connected all of the transactions and where they are processed. I also showed who pays for the transactions of food and adopting a pet. I showed where the foreign keys are to the best of my ability. I used crows foot notation on each connection to show that it could be one-to-one or one-to-many depedning on the situation.

# %% [markdown]
# ![Copy of Copy of LAB 2- Chris Ostir (1).png](data:image/png;base64,...)
